# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# C:\Users\saksh\Desktop\country-economic-stress-analysis

# %%
import os

for item in os.listdir():
    print(item)
# Out:
# .git
# .gitignore
# .ipynb_checkpoints
# 01_data_understanding.ipynb
# dashboards
# data
# desktop.ini
# docs
# LICENSE
# notebooks
# presentation
# README.md
# reports
# sql

# %%
import os

os.chdir("..")

print(os.getcwd())
# Out:
# C:\Users\saksh\Desktop
